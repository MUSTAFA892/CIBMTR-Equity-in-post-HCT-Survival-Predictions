# %% [markdown]
# Importing the dependencies

# %%
import pandas as pd

# %% [markdown]
# Importing the data

# %%
train_data = pd.read_csv(r'Datasets/train.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
train_data.isnull().sum()
# Out:
# ID                            0
# dri_score                   154
# psych_disturb              2062
# cyto_score                 8068
# diabetes                   2119
# hla_match_c_high           4620
# hla_high_res_8             5829
# tbi_status                    0
# arrhythmia                 2202
# hla_low_res_6              3270
# graft_type                    0
# vent_hist                   259
# renal_issue                1915
# pulm_severe                2135
# prim_disease_hct              0
# hla_high_res_6             5284
# cmv_status                  634
# hla_high_res_10            7163
# hla_match_dqb1_high        5199
# tce_imm_match             11133
# hla_nmdp_6                 4197
# hla_match_c_low            2800
# rituximab                  2148
# hla_match_drb1_low         2643
# hla_match_dqb1_low         4194
# prod_type                     0
# cyto_score_detail         11923
# conditioning_intensity     4789
# ethnicity                   587
# year_hct                      0
# obesity                    1760
# mrd_hct                   16597
# in_vivo_tcd                 225
# tce_match                 18996
# hla_match_a_high           4301
# hepatic_severe             1871
# donor_age                  1808
# prior_tumor                1678
# hla_match_b_low            2565
# peptic_ulcer               2419
# age_at_hct                    0
# hla_match_a_low            2390
# gvhd_proph                  225
# rheum_issue                2183
# sex_match                   261
# hla_match_b_high           4088
# race_group                    0
# comorbidity_score           477
# karnofsky_score             870
# hepatic_mild               1917
# tce_div_match             11396
# donor_related               158
# melphalan_dose             1405
# hla_low_res_8              3653
# cardiac                    2542
# hla_match_drb1_high        3352
# pulm_moderate              2047
# hla_low_res_10             5064
# efs                           0
# efs_time                      0
# dtype: int64

# %%
train_data.head()
# Out:
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type vent_hist renal_issue pulm_severe  \
# 0            6.0       Bone marrow        No          No          No
# 1            6.0  Peripheral blood        No          No          No
# 2            6.0       Bone marrow        No          No          No
# 3            6.0       Bone marrow        No          No          No
# 4            6.0  Peripheral blood        No          No          No
#
#   prim_disease_hct  hla_high_res_6 cmv_status  hla_high_res_10  \
# 0              IEA             6.0        +/+              NaN
# 1              AML             6.0        +/+             10.0
# 2              HIS             6.0        +/+             10.0
# 3              ALL             6.0        +/+             10.0
# 4              MPN             6.0        +/+             10.0
#
#    hla_match_dqb1_high tce_imm_match  hla_nmdp_6  hla_match_c_low rituximab  \
# 0                  2.0           NaN         6.0              2.0        No
# 1                  2.0           P/P         6.0              2.0        No
# 2                  2.0           P/P         6.0              2.0        No
# 3                  2.0           P/P         6.0              2.0        No
# 4                  2.0           NaN         5.0              2.0        No
#
#    hla_match_drb1_low  hla_match_dqb1_low prod_type cyto_score_detail  \
# 0                 2.0                 2.0        BM               NaN
# 1                 2.0                 2.0        PB      Intermediate
# 2                 2.0                 2.0        BM               NaN
# 3                 2.0                 2.0        BM      Intermediate
# 4                 2.0                 2.0        PB               NaN
#
#   conditioning_intensity               ethnicity  year_hct obesity   mrd_hct  \
# 0                    NaN  Not Hispanic or Latino      2016      No       NaN
# 1                    MAC  Not Hispanic or Latino      2008      No  Positive
# 2                    NaN  Not Hispanic or Latino      2019      No       NaN
# 3                    MAC  Not Hispanic or Latino      2009      No  Positive
# 4                    MAC      Hispanic or Latino      2018      No       NaN
#
#   in_vivo_tcd   tce_match  hla_match_a_high hepatic_severe  donor_age  \
# 0         Yes         NaN               2.0             No        NaN
# 1          No  Permissive               2.0             No      72.29
# 2         Yes         NaN               2.0             No        NaN
# 3          No  Permissive               2.0             No      29.23
# 4         Yes         NaN               2.0             No      56.81
#
#   prior_tumor  hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0          No              2.0           No       9.942              2.0
# 1          No              2.0           No      43.705              2.0
# 2          No              2.0           No      33.997              2.0
# 3          No              2.0           No      43.245              2.0
# 4          No              2.0           No      29.740              2.0
#
#                gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                 FKalone          No       M-F               2.0
# 1  Other GVHD Prophylaxis          No       F-F               2.0
# 2  Cyclophosphamide alone          No       F-M               2.0
# 3       FK+ MMF +- others          No       M-M               2.0
# 4     TDEPLETION +- other          No       M-F               2.0
#
#                          race_group  comorbidity_score  karnofsky_score  \
# 0                More than one race                0.0             90.0
# 1                             Asian                3.0             90.0
# 2                More than one race                0.0             90.0
# 3                             White                0.0             90.0
# 4  American Indian or Alaska Native                1.0             90.0
#
#   hepatic_mild          tce_div_match donor_related      melphalan_dose  \
# 0           No                    NaN     Unrelated  N/A, Mel not given
# 1           No  Permissive mismatched       Related  N/A, Mel not given
# 2           No  Permissive mismatched       Related  N/A, Mel not given
# 3          Yes  Permissive mismatched     Unrelated  N/A, Mel not given
# 4           No  Permissive mismatched       Related                 MEL
#
#    hla_low_res_8 cardiac  hla_match_drb1_high pulm_moderate  hla_low_res_10  \
# 0            8.0      No                  2.0            No            10.0
# 1            8.0      No                  2.0           Yes            10.0
# 2            8.0      No                  2.0            No            10.0
# 3            8.0      No                  2.0            No            10.0
# 4            8.0      No                  2.0            No            10.0
#
#    efs  efs_time
# 0  0.0    42.356
# 1  1.0     4.672
# 2  0.0    19.793
# 3  0.0   102.349
# 4  0.0    16.223

# %%
test_data = pd.read_csv(r'Datasets/test.csv')

# %%
test_data
# Out:
#       ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0  28800  N/A - non-malignant indication            No           NaN       No
# 1  28801                    Intermediate            No  Intermediate       No
# 2  28802  N/A - non-malignant indication            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
#
#    hla_low_res_6        graft_type vent_hist renal_issue pulm_severe  \
# 0            6.0       Bone marrow        No          No          No
# 1            6.0  Peripheral blood        No          No          No
# 2            6.0       Bone marrow        No          No          No
#
#   prim_disease_hct  hla_high_res_6 cmv_status  hla_high_res_10  \
# 0              IEA             6.0        +/+              NaN
# 1              AML             6.0        +/+             10.0
# 2              HIS             6.0        +/+             10.0
#
#    hla_match_dqb1_high tce_imm_match  hla_nmdp_6  hla_match_c_low rituximab  \
# 0                  2.0           NaN         6.0              2.0        No
# 1                  2.0           P/P         6.0              2.0        No
# 2                  2.0           P/P         6.0              2.0        No
#
#    hla_match_drb1_low  hla_match_dqb1_low prod_type cyto_score_detail  \
# 0                 2.0                 2.0        BM               NaN
# 1                 2.0                 2.0        PB      Intermediate
# 2                 2.0                 2.0        BM               NaN
#
#   conditioning_intensity               ethnicity  year_hct obesity   mrd_hct  \
# 0                    NaN  Not Hispanic or Latino      2016      No       NaN
# 1                    MAC  Not Hispanic or Latino      2008      No  Positive
# 2                    NaN  Not Hispanic or Latino      2019      No       NaN
#
#   in_vivo_tcd   tce_match  hla_match_a_high hepatic_severe  donor_age  \
# 0         Yes         NaN               2.0             No        NaN
# 1          No  Permissive               2.0             No      72.29
# 2         Yes         NaN               2.0             No        NaN
#
#   prior_tumor  hla_match_b_low peptic_ulcer  age_at_hct  hla_match_a_low  \
# 0          No              2.0           No       9.942              2.0
# 1          No              2.0           No      43.705              2.0
# 2          No              2.0           No      33.997              2.0
#
#                gvhd_proph rheum_issue sex_match  hla_match_b_high  \
# 0                 FKalone          No       M-F               2.0
# 1  Other GVHD Prophylaxis          No       F-F               2.0
# 2  Cyclophosphamide alone          No       F-M               2.0
#
#            race_group  comorbidity_score  karnofsky_score hepatic_mild  \
# 0  More than one race                0.0             90.0           No
# 1               Asian                3.0             90.0           No
# 2  More than one race                0.0             90.0           No
#
#            tce_div_match donor_related      melphalan_dose  hla_low_res_8  \
# 0                    NaN     Unrelated  N/A, Mel not given            8.0
# 1  Permissive mismatched       Related  N/A, Mel not given            8.0
# 2  Permissive mismatched       Related  N/A, Mel not given            8.0
#
#   cardiac  hla_match_drb1_high pulm_moderate  hla_low_res_10
# 0      No                  2.0            No            10.0
# 1      No                  2.0           Yes            10.0
# 2      No                  2.0            No            10.0

# %%
data_dict = pd.read_csv(r'Datasets/data_dictionary.csv')
data_dict.head()
# Out:
#            variable                                        description  \
# 0         dri_score                         Refined disease risk index
# 1     psych_disturb                            Psychiatric disturbance
# 2        cyto_score                                  Cytogenetic score
# 3          diabetes                                           Diabetes
# 4  hla_match_c_high  Recipient / 1st donor allele level (high resol...
#
#           type                                             values
# 0  Categorical  ['Intermediate' 'High' 'N/A - non-malignant in...
# 1  Categorical                        ['Yes' 'No' nan 'Not done']
# 2  Categorical  ['Intermediate' 'Favorable' 'Poor' 'TBD' nan '...
# 3  Categorical                        ['No' 'Yes' nan 'Not done']
# 4    Numerical                                                NaN

# %%
# Fill null values
for column in train_data.columns:
    if train_data[column].dtype == 'object':  # Categorical column
        train_data[column].fillna(train_data[column].mode()[0], inplace=True)
    else:  # Numerical column
        train_data[column].fillna(train_data[column].mean(), inplace=True)
# Out:
# C:\Users\Musta\AppData\Local\Temp\ipykernel_18848\1830311389.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[column].fillna(train_data[column].mean(), inplace=True)
# C:\Users\Musta\AppData\Local\Temp\ipykernel_18848\1830311389.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[column].fillna(train_data[column].mode()[0], inplace=True)

# %%
train_data.isnull().sum()
# Out:
# ID                        0
# dri_score                 0
# psych_disturb             0
# cyto_score                0
# diabetes                  0
# hla_match_c_high          0
# hla_high_res_8            0
# tbi_status                0
# arrhythmia                0
# hla_low_res_6             0
# graft_type                0
# vent_hist                 0
# renal_issue               0
# pulm_severe               0
# prim_disease_hct          0
# hla_high_res_6            0
# cmv_status                0
# hla_high_res_10           0
# hla_match_dqb1_high       0
# tce_imm_match             0
# hla_nmdp_6                0
# hla_match_c_low           0
# rituximab                 0
# hla_match_drb1_low        0
# hla_match_dqb1_low        0
# prod_type                 0
# cyto_score_detail         0
# conditioning_intensity    0
# ethnicity                 0
# year_hct                  0
# obesity                   0
# mrd_hct                   0
# in_vivo_tcd               0
# tce_match                 0
# hla_match_a_high          0
# hepatic_severe            0
# donor_age                 0
# prior_tumor               0
# hla_match_b_low           0
# peptic_ulcer              0
# age_at_hct                0
# hla_match_a_low           0
# gvhd_proph                0
# rheum_issue               0
# sex_match                 0
# hla_match_b_high          0
# race_group                0
# comorbidity_score         0
# karnofsky_score           0
# hepatic_mild              0
# tce_div_match             0
# donor_related             0
# melphalan_dose            0
# hla_low_res_8             0
# cardiac                   0
# hla_match_drb1_high       0
# pulm_moderate             0
# hla_low_res_10            0
# efs                       0
# efs_time                  0
# dtype: int64

# %% [markdown]
# Splitting values

# %%
X = train_data.drop(columns='efs')
Y = train_data['efs']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# Model Implementation

# %%
import xgboost as xgb


model = xgb.XGBRFRegressor()

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.fit(X_train,Y_train)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1752, in XGBRFRegressor.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1750 args = {k: v for k, v in locals().items() if k not in ("self", "__class__")}
#    1751 _check_rf_callback(early_stopping_rounds, callbacks)
# -> 1752 super().fit(**args)
#    1753 return self
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:988, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986 with config_context(verbosity=self.verbosity):
#     987     evals_result: TrainingCallback.EvalsLog = {}
# --> 988     train_dmatrix, evals = _wrap_evaluation_matrices(
#     989         missing=self.missing,
#     990         X=X,
#     991         y=y,
#     992         group=None,
#     993         qid=None,
#     994         sample_weight=sample_weight,
#     995         base_margin=base_margin,
#     996         feature_weights=feature_weights,
#     997         eval_set=eval_set,
#     998         sample_weight_eval_set=sample_weight_eval_set,
#     999         base_margin_eval_set=base_margin_eval_set,
#    1000         eval_group=None,
#    1001         eval_qid=None,
#    1002         create_dmatrix=self._create_dmatrix,
#    1003         enable_categorical=self.enable_categorical,
#    1004         feature_types=self.feature_types,
#    1005     )
#    1006     params = self.get_xgb_params()
#    1008     if callable(self.objective):
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:957, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     955     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     956 if _is_pandas_df(data):
# --> 957     return _from_pandas_df(data, enable_categorical, missing, threads,
#     958                            feature_names, feature_types)
#     959 if _is_pandas_series(data):
#     960     return _from_pandas_series(
#     961         data, missing, threads, enable_categorical, feature_names, feature_types
#     962     )
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:404, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     396 def _from_pandas_df(
#     397     data: DataFrame,
#     398     enable_categorical: bool,
#    (...)
#     402     feature_types: Optional[FeatureTypes],
#     403 ) -> DispatchedDataBackendReturnType:
# --> 404     data, feature_names, feature_types = _transform_pandas_df(
#     405         data, enable_categorical, feature_names, feature_types
#     406     )
#     407     return _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:378, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     366 from pandas.api.types import (
#     367     is_sparse,
#     368     is_categorical_dtype,
#     369 )
#     371 if not all(
#     372     dtype.name in _pandas_dtype_mapper
#     373     or is_sparse(dtype)
#    (...)
#     376     for dtype in data.dtypes
#     377 ):
# --> 378     _invalid_dataframe_dtype(data)
#     380 feature_names, feature_types = _pandas_feature_info(
#     381     data, meta, feature_names, feature_types, enable_categorical
#     382 )
#     384 transformed = _pandas_cat_null(data)
#
# File c:\Users\Musta\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:270, in _invalid_dataframe_dtype(data)
#     268 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     269 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 270 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:dri_score: object, psych_disturb: object, cyto_score: object, diabetes: object, tbi_status: object, arrhythmia: object, graft_type: object, vent_hist: object, renal_issue: object, pulm_severe: object, prim_disease_hct: object, cmv_status: object, tce_imm_match: object, rituximab: object, prod_type: object, cyto_score_detail: object, conditioning_intensity: object, ethnicity: object, obesity: object, mrd_hct: object, in_vivo_tcd: object, tce_match: object, hepatic_severe: object, prior_tumor: object, peptic_ulcer: object, gvhd_proph: object, rheum_issue: object, sex_match: object, race_group: object, hepatic_mild: object, tce_div_match: object, donor_related: object, melphalan_dose: object, cardiac: object, pulm_moderate: object
